# %%
import pandas as pd
import numpy as np
df = pd.read_csv("HIV DATASET 1.csv")
df
# Out:
#              PUBCHEM_RESULT_TAG  PUBCHEM_SID  PUBCHEM_CID  \
# 0                   RESULT_TYPE          NaN          NaN
# 1                  RESULT_DESCR          NaN          NaN
# 2                   RESULT_UNIT          NaN          NaN
# 3     RESULT_ATTR_CONC_MICROMOL          NaN          NaN
# 4                             1   49674668.0     171548.0
# ...                         ...          ...          ...
# 2019                       2016   85147408.0   44143164.0
# 2020                       2017   17409324.0  135511007.0
# 2021                       2018   99358167.0   44505346.0
# 2022                       2019   14725154.0    9549527.0
# 2023                       2020   49713889.0   23731297.0
#
#                           PUBCHEM_EXT_DATASOURCE_SMILES  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4          C1[C@H]2[C@@H]([C@@H](S1)CCCCC(=O)O)NC(=O)N2
# ...                                                 ...
# 2019  C1COCCN1C2=CC=C(C=C2)NCC3=CC4=C(C=C3)OCO4.C(=O...
# 2020          C1=C(C=C(C(=C1/C=N/NC2=NN=CN2N)O)Br)Br.Cl
# 2021  C[C@H]1CN(C(=O)CCCN2C(=CN=N2)CO[C@@H]1CN(C)S(=...
# 2022              CCCCCOC(=O)CC(C(=O)OCCCCC)N1CCCCC1.Cl
# 2023  C[C@]12[C@@H]3[C@H]([C@H](N1C(=O)CN(C2=O)CC4=C...
#
#      PUBCHEM_ACTIVITY_OUTCOME  PUBCHEM_ACTIVITY_SCORE  PUBCHEM_ACTIVITY_URL  \
# 0                         NaN                     NaN                   NaN
# 1                         NaN                     NaN                   NaN
# 2                         NaN                     NaN                   NaN
# 3                         NaN                     NaN                   NaN
# 4                      Active                   100.0                   NaN
# ...                       ...                     ...                   ...
# 2019                 Inactive                     0.0                   NaN
# 2020                 Inactive                     0.0                   NaN
# 2021                 Inactive                     0.0                   NaN
# 2022                 Inactive                     0.0                   NaN
# 2023                 Inactive                     0.0                   NaN
#
#       PUBCHEM_ASSAYDATA_COMMENT  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 2019                        NaN
# 2020                        NaN
# 2021                        NaN
# 2022                        NaN
# 2023                        NaN
#
#                            Average Inhibition at 3.7 uM  \
# 0                                                 FLOAT
# 1     Normalized percent inhibition of the confirmat...
# 2                                               PERCENT
# 3                                                   3.7
# 4                                                  95.9
# ...                                                 ...
# 2019                                             -15.76
# 2020                                             -15.92
# 2021                                             -16.57
# 2022                                             -17.16
# 2023                                             -17.23
#
#                                      Standard Deviation  \
# 0                                                 FLOAT
# 1     Standard deviation derived from the normalized...
# 2                                                  NONE
# 3                                                   NaN
# 4                                                0.3251
# ...                                                 ...
# 2019                                             1.2313
# 2020                                           0.427314
# 2021                                           0.606745
# 2022                                            2.53278
# 2023                                            1.11531
#
#                                Inhibition at 3.7 uM [1]  \
# 0                                                 FLOAT
# 1     Percent inhibition of the confirmation screen ...
# 2                                               PERCENT
# 3                                                   3.7
# 4                                               96.3489
# ...                                                 ...
# 2019                                           -17.1006
# 2020                                            -15.389
# 2021                                           -17.1335
# 2022                                           -19.0704
# 2023                                           -17.5683
#
#                                Inhibition at 3.7 uM [2]  \
# 0                                                 FLOAT
# 1     Percent inhibition of the confirmation screen ...
# 2                                               PERCENT
# 3                                                   3.7
# 4                                               95.5971
# ...                                                 ...
# 2019                                           -14.1296
# 2020                                           -16.4356
# 2021                                           -16.8397
# 2022                                           -18.8243
# 2023                                           -18.3954
#
#                                Inhibition at 3.7 uM [3]
# 0                                                 FLOAT
# 1     Percent inhibition of the confirmation screen ...
# 2                                               PERCENT
# 3                                                   3.7
# 4                                               95.7457
# ...                                                 ...
# 2019                                           -16.0647
# 2020                                           -15.9222
# 2021                                           -15.7249
# 2022                                           -13.5788
# 2023                                            -15.727
#
# [2024 rows x 13 columns]

# %%
df.drop([0,1,2,3], axis=0,inplace = True)
cols = ["PUBCHEM_EXT_DATASOURCE_SMILES", "PUBCHEM_ACTIVITY_OUTCOME"]
df = df[cols].reset_index()
df.drop("index", axis=1, inplace = True)
df.columns = ["SMILES", "ACTIVITY_OUTCOME"]
df.dropna(axis=0)
df
# Out:
#                                                  SMILES ACTIVITY_OUTCOME
# 0          C1[C@H]2[C@@H]([C@@H](S1)CCCCC(=O)O)NC(=O)N2           Active
# 1     C1=COC(=C1)/C=C/C=C\2/C(=O)N(C(=S)S2)C(CC(=O)O...           Active
# 2     C1=CC2=C(C(=C1)C3=C4C=CC(=O)C(=C4OC5=C3C=CC(=C...           Active
# 3                     C1=CC(=C(C=C1C[C@@H](C(=O)O)N)O)O           Active
# 4         C1C2=CC(=C(C=C2C3=C4C=CC(=O)C(=C4OCC31O)O)O)O           Active
# ...                                                 ...              ...
# 2015  C1COCCN1C2=CC=C(C=C2)NCC3=CC4=C(C=C3)OCO4.C(=O...         Inactive
# 2016          C1=C(C=C(C(=C1/C=N/NC2=NN=CN2N)O)Br)Br.Cl         Inactive
# 2017  C[C@H]1CN(C(=O)CCCN2C(=CN=N2)CO[C@@H]1CN(C)S(=...         Inactive
# 2018              CCCCCOC(=O)CC(C(=O)OCCCCC)N1CCCCC1.Cl         Inactive
# 2019  C[C@]12[C@@H]3[C@H]([C@H](N1C(=O)CN(C2=O)CC4=C...         Inactive
#
# [2020 rows x 2 columns]

# %%
def binarize(x):
    if x == "Active":
        return 1
    else:
        return 0

# %%
df["ACTIVITY"] = df["ACTIVITY_OUTCOME"].apply(binarize)
df.drop("ACTIVITY_OUTCOME", axis=1, inplace = True)
df
# Out:
#                                                  SMILES  ACTIVITY
# 0          C1[C@H]2[C@@H]([C@@H](S1)CCCCC(=O)O)NC(=O)N2         1
# 1     C1=COC(=C1)/C=C/C=C\2/C(=O)N(C(=S)S2)C(CC(=O)O...         1
# 2     C1=CC2=C(C(=C1)C3=C4C=CC(=O)C(=C4OC5=C3C=CC(=C...         1
# 3                     C1=CC(=C(C=C1C[C@@H](C(=O)O)N)O)O         1
# 4         C1C2=CC(=C(C=C2C3=C4C=CC(=O)C(=C4OCC31O)O)O)O         1
# ...                                                 ...       ...
# 2015  C1COCCN1C2=CC=C(C=C2)NCC3=CC4=C(C=C3)OCO4.C(=O...         0
# 2016          C1=C(C=C(C(=C1/C=N/NC2=NN=CN2N)O)Br)Br.Cl         0
# 2017  C[C@H]1CN(C(=O)CCCN2C(=CN=N2)CO[C@@H]1CN(C)S(=...         0
# 2018              CCCCCOC(=O)CC(C(=O)OCCCCC)N1CCCCC1.Cl         0
# 2019  C[C@]12[C@@H]3[C@H]([C@H](N1C(=O)CN(C2=O)CC4=C...         0
#
# [2020 rows x 2 columns]

# %%
df_new = df.copy()
df_new.drop_duplicates(inplace = True, ignore_index = True)
df_new.dropna(axis=0, inplace = True)
df_new
# Out:
#                                                  SMILES  ACTIVITY
# 0          C1[C@H]2[C@@H]([C@@H](S1)CCCCC(=O)O)NC(=O)N2         1
# 1     C1=COC(=C1)/C=C/C=C\2/C(=O)N(C(=S)S2)C(CC(=O)O...         1
# 2     C1=CC2=C(C(=C1)C3=C4C=CC(=O)C(=C4OC5=C3C=CC(=C...         1
# 3                     C1=CC(=C(C=C1C[C@@H](C(=O)O)N)O)O         1
# 4         C1C2=CC(=C(C=C2C3=C4C=CC(=O)C(=C4OCC31O)O)O)O         1
# ...                                                 ...       ...
# 2015  C1COCCN1C2=CC=C(C=C2)NCC3=CC4=C(C=C3)OCO4.C(=O...         0
# 2016          C1=C(C=C(C(=C1/C=N/NC2=NN=CN2N)O)Br)Br.Cl         0
# 2017  C[C@H]1CN(C(=O)CCCN2C(=CN=N2)CO[C@@H]1CN(C)S(=...         0
# 2018              CCCCCOC(=O)CC(C(=O)OCCCCC)N1CCCCC1.Cl         0
# 2019  C[C@]12[C@@H]3[C@H]([C@H](N1C(=O)CN(C2=O)CC4=C...         0
#
# [2020 rows x 2 columns]

# %%
df_new.to_csv("HIV smalldata.csv", index=False)
